# %% [markdown]
# # This is a practice cleaning data from a messy data set

# %% [markdown]
# ## Set up

# %%
import pandas as pd

pd.set_option('display.max_row',100)
pd.set_option('display.max_column',2000)

# %% [markdown]
# ## Read & observing data file

# %%
raw_file = pd.read_csv("fifa21 raw data v2.csv",low_memory=False)
raw_file.head()
# Out:
#        ID               Name                      LongName  \
# 0  158023           L. Messi                  Lionel Messi
# 1   20801  Cristiano Ronaldo  C. Ronaldo dos Santos Aveiro
# 2  200389           J. Oblak                     Jan Oblak
# 3  192985       K. De Bruyne               Kevin De Bruyne
# 4  190871          Neymar Jr    Neymar da Silva Santos Jr.
#
#                                            photoUrl  \
# 0  https://cdn.sofifa.com/players/158/023/21_60.png
# 1  https://cdn.sofifa.com/players/020/801/21_60.png
# 2  https://cdn.sofifa.com/players/200/389/21_60.png
# 3  https://cdn.sofifa.com/players/192/985/21_60.png
# 4  https://cdn.sofifa.com/players/190/871/21_60.png
#
#                                            playerUrl Nationality  Age  ↓OVA  \
# 0  http://sofifa.com/player/158023/lionel-messi/2...   Argentina   33    93
# 1  http://sofifa.com/player/20801/c-ronaldo-dos-s...    Portugal   35    92
# ...

# %%
raw_file.shape
# Out:
# (18979, 77)

# %%
raw_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18979 entries, 0 to 18978
# Data columns (total 77 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                18979 non-null  int64
#  1   Name              18979 non-null  object
#  2   LongName          18979 non-null  object
#  3   photoUrl          18979 non-null  object
#  4   playerUrl         18979 non-null  object
#  5   Nationality       18979 non-null  object
#  6   Age               18979 non-null  int64
#  7   ↓OVA              18979 non-null  int64
#  8   POT               18979 non-null  int64
#  9   Club              18979 non-null  object
#  10  Contract          18979 non-null  object
#  11  Positions         18979 non-null  object
#  12  Height            18979 non-null  object
#  13  Weight            18979 non-null  object
#  14  Preferred Foot    18979 non-null  object
#  15  BOV               18979 non-null  int64
# ...

# %%
raw_file.describe()
# Out:
#                   ID           Age          ↓OVA           POT           BOV  \
# count   18979.000000  18979.000000  18979.000000  18979.000000  18979.000000
# mean   226403.384794     25.194109     65.718636     71.136414     66.751726
# std     27141.054157      4.710520      6.968999      6.114635      6.747193
# min        41.000000     16.000000     47.000000     47.000000     48.000000
# 25%    210135.000000     21.000000     61.000000     67.000000     62.000000
# 50%    232418.000000     25.000000     66.000000     71.000000     67.000000
# 75%    246922.500000     29.000000     70.000000     75.000000     71.000000
# max    259216.000000     53.000000     93.000000     95.000000     93.000000
#
#           Attacking      Crossing     Finishing  Heading Accuracy  \
# count  18979.000000  18979.000000  18979.000000      18979.000000
# mean     248.938142     49.688392     45.842405         51.942726
# std       74.299428     18.131153     19.567081         17.294409
# ...

# %% [markdown]
# ## Column Loan Date End, Hits contains missing data.

# %% [markdown]
# #### Drop LongName, photoUrl, playerUrl
# > Long Name: isn't required as already have a Name column
# >
# > photoUrl & playerUrl: Irrelevant information for dataset
# #### Remove ↓ in OVA names.
# #### Remove Extra line in Club Data,
# #### Spiliting Contract to "Contract Start Year" and "Contract End Year"
# #### Remove special character in Value, Wage and Release Clause (M,K,€)
# #### Remove START ★ in W/F, SM, IR
# #### Modified column name, Height to Height in CM and remove the cm in data
# #### Modified column name, Weight to Weight in kg and remove the kg in data.

# %%
raw_file = raw_file.drop(columns=["LongName","photoUrl","playerUrl"])

# %% [markdown]
# ### Check duplicate data

# %%
raw_file[raw_file["Name"].duplicated()]
# Out:
#            ID        Name          Nationality  Age  ↓OVA  POT  \
# 498    162240  M. Dembélé              Belgium   32    80   80
# 574    216531    Paulinho             Portugal   27    79   80
# 598    202642    Fernando               Brazil   28    79   80
# 685    168607     Rafinha               Brazil   34    79   79
# 694    247204     Emerson               Brazil   21    78   88
# ...       ...         ...                  ...  ...   ...  ...
# 18913  256415   M. Harris  Republic of Ireland   17    49   62
# 18925  256602  S. Navarro             Colombia   19    48   61
# 18931  256552  D. Aravena                Chile   19    48   61
# 18933  253168    J. Smith              England   18    48   63
# 18960  251263    L. Smith              England   19    48   65
#
#                                   Club     Contract     Positions Height  \
# 498           \n\n\n\nGuangzhou R&F FC  2019 ~ 2021  CM, CAM, CDM  185cm
# ...

# %%
raw_file[raw_file["Name"] == "M. Dembélé"]
# Out:
#            ID        Name Nationality  Age  ↓OVA  POT  \
# 315    211591  M. Dembélé      France   23    81   85
# 498    162240  M. Dembélé     Belgium   32    80   80
# 14057  238627  M. Dembélé      France   23    61   69
# 16326  243540  M. Dembélé      France   21    58   69
#
#                                  Club     Contract     Positions Height  \
# 315        \n\n\n\nOlympique Lyonnais  2018 ~ 2023            ST  183cm
# 498          \n\n\n\nGuangzhou R&F FC  2019 ~ 2021  CM, CAM, CDM  185cm
# 14057  \n\n\n\nRodez Aveyron Football  2020 ~ 2022        ST, LM  184cm
# 16326            \n\n\n\nESTAC Troyes  2019 ~ 2022        CB, RB  186cm
#
#       Weight Preferred Foot  BOV Best Position        Joined Loan Date End  \
# 315     74kg          Right   83            ST  Aug 31, 2018           NaN
# 498     85kg           Left   80            CM  Jan 17, 2019           NaN
# 14057   75kg          Right   63            ST  Jul 10, 2020           NaN
# ...

# %% [markdown]
# ### There are a few duplicate data in the name, but turns out they have different stats, so they might be different person sharing similar names.

# %%
raw_file["Club"] = raw_file["Club"].str.strip("\n")

# %%
raw_file
# Out:
# 0               FC Barcelona
# 1                   Juventus
# 2            Atlético Madrid
# 3            Manchester City
# 4        Paris Saint-Germain
#                 ...
# 18974             Wuhan Zall
# 18975        Oldham Athletic
# 18976             Derry City
# 18977       Dalian YiFang FC
# 18978       Dalian YiFang FC
# Name: Club, Length: 18979, dtype: object
